# %% [markdown]
# ### Why we only get data up to 2025 and not before?
# ### Why the deprecated warnings?

# %%
import pystac_client

catalog = pystac_client.Client.open(
    "https://stac.core.eopf.eodc.eu"
)

# %%
bbox_villaviciosa = [
    -5.432,   # min lon
    43.497,  # min lat
    -5.374,   # max lon
    43.534   # max lat
]

temporal_extent = ["2022-01-01", None] 

items = list(
    catalog.search(
        collections=["sentinel-2-l2a"],
        bbox=bbox_villaviciosa,
        datetime=temporal_extent,
        #query={"eo:cloud_cover": {"lt": 20}},
    ).items()
)
print(f"Found {len(items)} Sentinel-2 L2A products")
for item in items:
    print(item.datetime)
# Out:
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20251104T112139_N0511_R037_T30TUP_20251104T134759' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20251104T112139_N0511_R037_T29TQJ_20251104T134759' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20251101T112241_N0511_R037_T30TUP_20251101T151319' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20251101T112241_N0511_R037_T29TQJ_20251101T151319' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20251101T111119_N0511_R137_T30TUP_20251101T135730' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20251101T111119_N0511_R137_T29TQJ_20251101T135730' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250405T112131_N0511_R037_T30TUP_20250405T182117' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250405T112131_N0511_R037_T29TQJ_20250405T182117' is deprecated.
#   warnings.warn(
# Found 194 Sentinel-2 L2A products
# 2026-02-02 11:21:59.024000+00:00
# 2026-02-02 11:21:59.024000+00:00
# 2026-01-30 11:12:09.025000+00:00
# 2026-01-30 11:12:09.025000+00:00
# 2026-01-28 11:23:21.025000+00:00
# 2026-01-28 11:23:21.025000+00:00
# 2026-01-25 11:13:41.025000+00:00
# 2026-01-25 11:13:41.025000+00:00
# 2026-01-23 11:22:49.024000+00:00
# 2026-01-23 11:22:49.024000+00:00
# 2026-01-18 11:24:11.025000+00:00
# 2026-01-18 11:24:11.025000+00:00
# 2026-01-15 11:14:21.025000+00:00
# 2026-01-15 11:14:21.025000+00:00
# 2026-01-13 11:23:29.024000+00:00
# 2026-01-13 11:23:29.024000+00:00
# 2026-01-10 11:21:31.024000+00:00
# 2026-01-10 11:21:31.024000+00:00
# 2026-01-10 11:13:39.024000+00:00
# 2026-01-10 11:13:39.024000+00:00
# 2026-01-08 11:24:51.025000+00:00
# 2026-01-03 11:23:59.024000+00:00
# 2025-12-31 11:13:59.024000+00:00
# 2025-12-31 11:13:59.024000+00:00
# 2025-12-29 11:25:11.025000+00:00
# 2025-12-28 11:15:21.024000+00:00
# 2025-12-26 11:15:01.025000+00:00
# 2025-12-21 11:25:21.024000+00:00
# 2025-12-21 11:13:59.024000+00:00
# 2025-12-19 11:25:11.025000+00:00
# 2025-12-18 11:15:11.024000+00:00
# 2025-12-18 11:15:11.024000+00:00
# 2025-12-16 11:15:01.025000+00:00
# 2025-12-16 11:15:01.025000+00:00
# 2025-12-14 11:23:59.024000+00:00
# 2025-12-14 11:23:59.024000+00:00
# 2025-12-11 11:25:11.024000+00:00
# 2025-12-11 11:25:11.024000+00:00
# 2025-12-11 11:13:49.024000+00:00
# 2025-12-11 11:13:49.024000+00:00
# 2025-12-11 11:13:49.024000+00:00
# 2025-04-20 11:06:41.025000+00:00
# 2025-04-20 11:06:41.025000+00:00
# 2025-04-18 11:21:19.024000+00:00
# 2025-04-18 11:21:19.024000+00:00
# 2025-04-15 11:21:31.024000+00:00
# 2025-04-15 11:21:31.024000+00:00
# 2025-04-15 11:06:19.024000+00:00
# 2025-04-15 11:06:19.024000+00:00
# 2025-04-13 11:21:31.025000+00:00
# 2025-04-10 11:06:41.025000+00:00
# 2025-04-08 11:21:19.024000+00:00
# 2025-04-05 11:21:31.024000+00:00
# 2025-04-05 11:21:31.024000+00:00
# 2025-04-05 11:06:19.024000+00:00
# 2025-04-05 11:06:19.024000+00:00
# 2024-12-04 11:24:41.024000+00:00
# 2024-12-01 11:14:31.024000+00:00
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250405T110619_N0511_R137_T30TUP_20250405T140215' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250405T110619_N0511_R137_T29TQJ_20250405T140215' is deprecated.
#   warnings.warn(

# %% [markdown]
# ### Also when loading STAC items into xarray, some seem to be actually missing

# %%
import xarray as xr
from pyproj import Transformer

datasets, included, skipped, crs_list = [], [], [], []

for item in items:
    url = item.assets["product"].href

    # --- Try to open dataset ---
    try:
        ds = xr.open_dataset(url, engine="eopf-zarr", chunks={})
    except Exception as e:
        print(f"\n-{e}")
        skipped.append(url)
        continue

    # --- Get CRS ---
    crs = ds.rio.crs
    print(f"\n-{url.split('/')[-1]}")
    print(f"   CRS: {crs}")

    if crs is None:
        print("   No CRS found, skipping")
        skipped.append(url)
        continue

    # --- Reproject WGS84 bbox to dataset CRS ---
    transformer = Transformer.from_crs("EPSG:4326", crs, always_xy=True)
    minx, miny = transformer.transform(bbox_villaviciosa[0], bbox_villaviciosa[1])
    maxx, maxy = transformer.transform(bbox_villaviciosa[2], bbox_villaviciosa[3])

    # --- Handle Y axis direction ---
    y_slice = slice(maxy, miny) if ds.y[0] > ds.y[-1] else slice(miny, maxy)

    # --- Clip ---
    ds_clipped = ds.sel(x=slice(minx, maxx), y=y_slice)

    if ds_clipped.sizes["x"] == 0 or ds_clipped.sizes["y"] == 0:
        print("   No overlap with bbox after reprojection")
        skipped.append(url)
        continue

    print(f"   Clipped size: {dict(ds_clipped.sizes)}")

    # --- Store dataset ---
    datasets.append(ds_clipped)
    included.append(url)
    crs_list.append(crs)

print(f"\n✓ Included: {len(included)} | ✗ Skipped: {len(skipped)}")
# Out:
# -S2B_MSIL2A_20260202T112159_N0511_R037_T30TUP_20260202T151511.zarr
#    CRS: EPSG:32630
#    Clipped size: {'x': 481, 'y': 398}
#
# -S2B_MSIL2A_20260202T112159_N0511_R037_T29TQJ_20260202T151511.zarr
#    CRS: EPSG:32629
#    Clipped size: {'x': 451, 'y': 432}
#
# -S2B_MSIL2A_20260130T111209_N0511_R137_T30TUP_20260130T150430.zarr
#    CRS: EPSG:32630
#    Clipped size: {'x': 481, 'y': 398}
#
# -S2B_MSIL2A_20260130T111209_N0511_R137_T29TQJ_20260130T150430.zarr
#    CRS: EPSG:32629
#    Clipped size: {'x': 451, 'y': 432}
#
# -S2C_MSIL2A_20260128T112321_N0511_R037_T30TUP_20260128T151411.zarr
#    CRS: EPSG:32630
#    Clipped size: {'x': 481, 'y': 398}
#
# -S2C_MSIL2A_20260128T112321_N0511_R037_T29TQJ_20260128T151411.zarr
#    CRS: EPSG:32629
#    Clipped size: {'x': 451, 'y': 432}
#
# -S2C_MSIL2A_20260125T111341_N0511_R137_T30TUP_20260125T145411.zarr
#    CRS: EPSG:32630
#    Clipped size: {'x': 481, 'y': 398}
#
# -S2C_MSIL2A_20260125T111341_N0511_R137_T29TQJ_20260125T145411.zarr
#    CRS: EPSG:32629
#    Clipped size: {'x': 451, 'y': 432}
#
# -S2B_MSIL2A_20260123T112249_N0511_R037_T30TUP_20260123T133836.zarr
#    CRS: EPSG:32630
#    Clipped size: {'x': 481, 'y': 398}
#
# -S2B_MSIL2A_20260123T112249_N0511_R037_T29TQJ_20260123T133836.zarr
#    CRS: EPSG:32629
#    Clipped size: {'x': 451, 'y': 432}
#
# -S2C_MSIL2A_
zarr
#    CRS: EPSG:32630
#    Clipped size: {'x': 481, 'y': 398}
#
# -S2C_MSIL2A_20250420T110641_N0511_R137_T29TQJ_20250420T163029.zarr
#    CRS: EPSG:32629
#    Clipped size: {'x': 451, 'y': 432}
#
# -S2B_MSIL2A_20250418T112119_N0511_R037_T30TUP_20250418T133042.zarr
#    CRS: EPSG:32630
#    Clipped size: {'x': 481, 'y': 398}
#
# -S2B_MSIL2A_20250418T112119_N0511_R037_T29TQJ_20250418T133042.zarr
#    CRS: EPSG:32629
#    Clipped size: {'x': 451, 'y': 432}
#
# -S2A_MSIL2A_20250415T112131_N0511_R037_T30TUP_20250415T194712.zarr
#    CRS: EPSG:32630
#    Clipped size: {'x': 481, 'y': 398}
#
# -S2A_MSIL2A_20250415T112131_N0511_R037_T29TQJ_20250415T194712.zarr
#    CRS: EPSG:32629
#    Clipped size: {'x': 451, 'y': 432}
#
# -S2B_MSIL2A_20250415T110619_N0511_R137_T30TUP_20250415T140506.zarr
#    CRS: EPSG:32630
#    Clipped size: {'x': 481, 'y': 398}
#
# -S2B_MSIL2A_20250415T110619_N0511_R137_T29TQJ_20250415T140506.zarr
#    CRS: EPSG:32629
#    Clipped size: {'x': 451, 'y': 432}
#
# -S2C_MSIL2A_20250413T112131_N0511_R037_T30TUP_20250413T164713.zarr
#    CRS: EPSG:32630
#    Clipped size: {'x': 481, 'y': 398}
#
# -S2C_MSIL2A_20250410T110641_N0511_R137_T29TQJ_20250410T164104.zarr
#    CRS: EPSG:32629
#    Clipped size: {'x': 451, 'y': 432}
#
# -S2B_MSIL2A_20250408T112119_N0511_R037_T29TQJ_20250408T133525.zarr
#    CRS: EPSG:32629
#    Clipped size: {'x': 451, 'y': 432}
#
# -No such file or directory: 'https://objectstore.eodc.eu:2222/e05ab01a9d56408d82ac32d69a5aae2a:202504-s02msil2a/05/products/cpm_v256/S2A_MSIL2A_20250405T112131_N0511_R037_T30TUP_20250405T182117.zarr'
#
# -No such file or directory: 'https://objectstore.eodc.eu:2222/e05ab01a9d56408d82ac32d69a5aae2a:202504-s02msil2a/05/products/cpm_v256/S2A_MSIL2A_20250405T112131_N0511_R037_T29TQJ_20250405T182117.zarr'
#
# -No such file or directory: 'https://objectstore.eodc.eu:2222/e05ab01a9d56408d82ac32d69a5aae2a:202504-s02msil2a/05/products/cpm_v256/S2B_MSIL2A_20250405T110619_N0511_R137_T30TUP_20250405T140215.zarr'
#
# -No such file or directory: 'https://objectstore.eodc.eu:2222/e05ab01a9d56408d82ac32d69a5aae2a:202504-s02msil2a/05/products/cpm_v256/S2B_MSIL2A_20250405T110619_N0511_R137_T29TQJ_20250405T140215.zarr'
#
# -S2A_MSIL2A_20241204T112441_N0511_R037_T30TUP_20241204T145548.zarr
#    CRS: EPSG:32630
#    Clipped size: {'x': 481, 'y': 398}
#
# -S2A_MSIL2A_20241201T111431_N0511_R137_T29TQJ_20241201T152748.zarr
#    CRS: EPSG:32629
#    Clipped size: {'x': 451, 'y': 432}
#
# ✓ Included: 153 | ✗ Skipped: 41

# %% [markdown]
# ### Maybe this is related with x-cube failing?

# %%
from xcube.core.store import new_data_store
from xcube.util.config import load_configs
from xcube.webapi.viewer import Viewer
from xcube_resampling.utils import reproject_bbox

# %%
store = new_data_store("eopf-zarr")
store.list_data_ids()
# Out:
# ['sentinel-2-l1c',
#  'sentinel-2-l2a',
#  'sentinel-3-olci-l1-efr',
#  'sentinel-3-olci-l2-lfr',
#  'sentinel-3-slstr-l1-rbt',
#  'sentinel-3-slstr-l2-lst']

# %%
crs_utm = "EPSG:32630"
bbox_utm = reproject_bbox(bbox_villaviciosa, "EPSG:4326", crs_utm)

# %%
ds = store.open_data(
    data_id="sentinel-2-l2a",
    bbox=bbox_utm, # bbox in degrees can also be used
    time_range=temporal_extent,
    spatial_res=10, # in that case convert m to degrees: 10 / 111320 
    crs=crs_utm, # and change to EPSG:4326
    variables=["b01", "b02", "b03", "b04", "scl"],
)
ds
# Out:
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20251104T112139_N0511_R037_T30TUP_20251104T134759' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20251104T112139_N0511_R037_T29TQJ_20251104T134759' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20251101T112241_N0511_R037_T30TUP_20251101T151319' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20251101T112241_N0511_R037_T29TQJ_20251101T151319' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20251101T111119_N0511_R137_T30TUP_20251101T135730' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20251101T111119_N0511_R137_T29TQJ_20251101T135730' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250405T112131_N0511_R037_T30TUP_20250405T182117' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250405T112131_N0511_R037_T29TQJ_20250405T182117' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250405T110619_N0511_R137_T30TUP_20250405T140215' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250405T110619_N0511_R137_T29TQJ_20250405T140215' is deprecated.
#   warnings.warn(
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/fsspec/mapping.py:155, in FSMap.__getitem__(self, key, default)
#     154 try:
# --> 155     result = self.fs.cat(k)
#     156 except self.missing_exceptions as exc:
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/fsspec/asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     117 self = obj or args[0]
# --> 118 return sync(self.loop, func, *args, **kwargs)
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/fsspec/asyn.py:103, in sync(loop, func, timeout, *args, **kwargs)
#     102 elif isinstance(return_result, BaseException):
# --> 103     raise return_result
#     104 else:
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/fsspec/asyn.py:56, in _runner(event, coro, result, timeout)
#      55 try:
# ---> 56     result[0] = await coro
#      57 except Exception as ex:
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/fsspec/asyn.py:469, in AsyncFileSystem._cat(self, path, recursive, on_error, batch_size, **kwargs)
#     468     if ex:
# --> 469         raise ex
#     470 if (
#     471     len(paths) > 1
#     472     or isinstance(path, list)
#     473     or paths[0] != self._strip_protocol(path)
#     474 ):
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/fsspec/asyn.py:244, in _run_coros_in_chunks.<locals>._run_coro(coro, i)
#     243 try:
# --> 244     return await asyncio.wait_for(coro, timeout=timeout), i
#     245 except Exception as e:
#
# File ~/anaconda3/envs/landscape/lib/python3.13/asyncio/tasks.py:507, in wait_for(fut, timeout)
#     506 async with timeouts.timeout(timeout):
# --> 507     return await fut
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/fsspec/implementations/http.py:247, in HTTPFileSystem._cat_file(self, url, start, end, **kwargs)
#     246     out = await r.read()
# --> 247     self._raise_not_found_for_status(r, url)
#     248 return out
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/fsspec/implementations/http.py:229, in HTTPFileSystem._raise_not_found_for_status(self, response, url)
#     228 if response.status == 404:
# --> 229     raise FileNotFoundError(url)
#     230 response.raise_for_status()
#
# FileNotFoundError: https://objects.eodc.eu:443/e05ab01a9d56408d82ac32d69a5aae2a:202509-s02msil2a-eu/25/products/cpm_v256/S2B_MSIL2A_20250925T112109_N0511_R037_T29TQJ_20250925T151904.zarr/.zmetadata
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/zarr/storage.py:1446, in FSStore.__getitem__(self, key)
#    1445 try:
# -> 1446     return self.map[key]
#    1447 except self.exceptions as e:
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/fsspec/mapping.py:159, in FSMap.__getitem__(self, key, default)
#     158         return default
# --> 159     raise KeyError(key) from exc
#     160 return result
#
# KeyError: '.zmetadata'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/backends/zarr.py:1874, in _get_open_params(store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, zarr_version, use_zarr_fill_value_as_mask, zarr_format)
#    1873 try:
# -> 1874     zarr_root_group = zarr.open_consolidated(store, **open_kwargs)
#    1875 except (ValueError, KeyError):
#    1876     # ValueError in zarr-python 3.x, KeyError in 2.x.
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/zarr/convenience.py:1362, in open_consolidated(store, metadata_key, mode, **kwargs)
#    1361 # setup metadata store
# -> 1362 meta_store = ConsolidatedStoreClass(store, metadata_key=metadata_key)
#    1364 # pass through
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/zarr/storage.py:3045, in ConsolidatedMetadataStore.__init__(self, store, metadata_key)
#    3044 # retrieve consolidated metadata
# -> 3045 meta = json_loads(self.store[metadata_key])
#    3047 # check format of consolidated metadata
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/zarr/storage.py:1448, in FSStore.__getitem__(self, key)
#    1447 except self.exceptions as e:
# -> 1448     raise KeyError(key) from e
#
# KeyError: '.zmetadata'
#
# During handling of the above exception, another exception occurred:
#
# GroupNotFoundError                        Traceback (most recent call last)
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/backends/zarr.py:1878, in _get_open_params(store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, zarr_version, use_zarr_fill_value_as_mask, zarr_format)
#    1877 try:
# -> 1878     zarr_root_group = zarr.open_group(store, **open_kwargs)
#    1879     emit_user_level_warning(
#    1880         "Failed to open Zarr store with consolidated metadata, "
#    1881         "but successfully read with non-consolidated metadata. "
#    (...)
#    1891         RuntimeWarning,
#    1892     )
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/zarr/hierarchy.py:1578, in open_group(store, mode, cache_attrs, synchronizer, path, chunk_store, storage_options, zarr_version, meta_array)
#    1577             raise ContainsArrayError(path)
# -> 1578         raise GroupNotFoundError(path)
#    1580 elif mode == "w":
#
# GroupNotFoundError: group not found at path ''
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 ds = store.open_data(
#       2     data_id="sentinel-2-l2a",
#       3     bbox=bbox_utm, # bbox in degrees can also be used
#       4     time_range=temporal_extent,
#       5     spatial_res=10, # in that case convert m to degrees: 10 / 111320
#       6     crs=crs_utm, # and change to EPSG:4326
#       7     variables=["b01", "b02", "b03", "b04", "scl"],
#       8 )
#       9 ds
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xcube_eopf/store.py:123, in EOPFZarrDataStore.open_data(self, data_id, opener_id, data_type, **open_params)
#     120 if len(items) == 0:
#     121     raise DataStoreError(f"No items found for search_params {search_params}.")
# --> 123 return product_handler.open_data(items, **open_params)
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xcube_eopf/prodhandlers/sentinel2.py:102, in Sen2ProductHandler.open_data(self, items, **open_params)
#      99 grouped_items = group_items(items)
#     101 # generate cube by mosaicking and stacking tiles
# --> 102 ds = generate_cube(grouped_items, **open_params)
#     104 # add attributes
#     105 ds = add_attributes(ds, grouped_items, **open_params)
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xcube_eopf/prodhandlers/sentinel2.py:239, in generate_cube(grouped_items, **open_params)
#     237 list_ds_utm = []
#     238 for crs, tile_ids in utm_tile_id.items():
# --> 239     ds = _generate_utm_cube(grouped_items.sel(tile_id=tile_ids), crs, **open_params)
#     240     list_ds_utm.append(ds)
#     242 # Reproject datasets from different UTM zones to a common grid reference system
#     243 # and merge them into a single unified dataset for seamless spatial analysis.
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xcube_eopf/prodhandlers/sentinel2.py:290, in _generate_utm_cube(grouped_items, crs_utm, **open_params)
#     288 multi_tiles = []
#     289 for item in items:
# --> 290     ds = xr.open_dataset(
#     291         item.assets["product"].href,
#     292         engine="eopf-zarr",
#     293         chunks={},
#     294         **xarray_open_params,
#     295     )
#     296     ds = ds.sel(
#     297         x=slice(final_bbox[0], final_bbox[2]),
#     298         y=slice(final_bbox[3], final_bbox[1]),
#     299     )
#     300     if any(size == 0 for size in ds.sizes.values()):
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/backends/api.py:606, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, create_default_indexes, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     594 decoders = _resolve_decoders_kwargs(
#     595     decode_cf,
#     596     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     602     decode_coords=decode_coords,
#     603 )
#     605 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 606 backend_ds = backend.open_dataset(
#     607     filename_or_obj,
#     608     drop_variables=drop_variables,
#     609     **decoders,
#     610     **kwargs,
#     611 )
#     612 ds = _dataset_from_backend_dataset(
#     613     backend_ds,
#     614     filename_or_obj,
#    (...)
#     625     **kwargs,
#     626 )
#     627 return ds
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray_eopf/backend.py:196, in EopfBackend.open_dataset(self, filename_or_obj, op_mode, storage_options, group_sep, variables, product_type, resolution, bbox, crs, interp_methods, agg_methods, drop_variables, decode_timedelta)
#     192 xr.set_options(display_expand_attrs=False)
#     194 assert_arg_is_one_of(op_mode, "op_mode", OP_MODES)
# --> 196 datatree = self.open_datatree(
#     197     filename_or_obj,
#     198     op_mode="native",
#     199     storage_options=storage_options,
#     200     # here as it is required for all backends
#     201     drop_variables=drop_variables,
#     202     # here to silence xarray warnings
#     203     decode_timedelta=decode_timedelta,
#     204 )
#     206 _assert_datatree_is_chunked(datatree)
#     208 if op_mode == OP_MODE_NATIVE:
#     209     # native mode
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray_eopf/backend.py:84, in EopfBackend.open_datatree(self, filename_or_obj, op_mode, product_type, storage_options, drop_variables, decode_timedelta)
#      81 source = normalize_source(filename_or_obj, storage_options)
#      83 # noinspection PyTypeChecker
# ---> 84 datatree = xr.open_datatree(
#      85     source,
#      86     engine="zarr",
#      87     group=subgroup_path,
#      88     # prefer the chunking from the Zarr metadata
#      89     chunks={},
#      90     # here as it is required for all backends
#      91     drop_variables=drop_variables,
#      92     # here to silence xarray warnings
#      93     decode_timedelta=decode_timedelta,
#      94 )
#      96 _assert_datatree_is_chunked(datatree)
#      98 if op_mode == OP_MODE_NATIVE:
#      99     # native mode, so we return tree as-is
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/backends/api.py:1076, in open_datatree(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, create_default_indexes, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#    1064 decoders = _resolve_decoders_kwargs(
#    1065     decode_cf,
#    1066     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#    1072     decode_coords=decode_coords,
#    1073 )
#    1074 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# -> 1076 backend_tree = backend.open_datatree(
#    1077     filename_or_obj,
#    1078     drop_variables=drop_variables,
#    1079     **decoders,
#    1080     **kwargs,
#    1081 )
#    1083 tree = _datatree_from_backend_datatree(
#    1084     backend_tree,
#    1085     filename_or_obj,
#    (...)
#    1096     **kwargs,
#    1097 )
#    1099 return tree
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/backends/zarr.py:1716, in ZarrBackendEntrypoint.open_datatree(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, synchronizer, consolidated, chunk_store, storage_options, zarr_version, zarr_format)
#    1695 def open_datatree(
#    1696     self,
#    1697     filename_or_obj: T_PathFileOrDataStore,
#    (...)
#    1713     zarr_format=None,
#    1714 ) -> DataTree:
#    1715     filename_or_obj = _normalize_path(filename_or_obj)
# -> 1716     groups_dict = self.open_groups_as_dict(
#    1717         filename_or_obj=filename_or_obj,
#    1718         mask_and_scale=mask_and_scale,
#    1719         decode_times=decode_times,
#    1720         concat_characters=concat_characters,
#    1721         decode_coords=decode_coords,
#    1722         drop_variables=drop_variables,
#    1723         use_cftime=use_cftime,
#    1724         decode_timedelta=decode_timedelta,
#    1725         group=group,
#    1726         mode=mode,
#    1727         synchronizer=synchronizer,
#    1728         consolidated=consolidated,
#    1729         chunk_store=chunk_store,
#    1730         storage_options=storage_options,
#    1731         zarr_version=zarr_version,
#    1732         zarr_format=zarr_format,
#    1733     )
#    1735     return datatree_from_dict_with_io_cleanup(groups_dict)
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/backends/zarr.py:1765, in ZarrBackendEntrypoint.open_groups_as_dict(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, synchronizer, consolidated, chunk_store, storage_options, zarr_version, zarr_format)
#    1762 else:
#    1763     parent = str(NodePath("/"))
# -> 1765 stores = ZarrStore.open_store(
#    1766     filename_or_obj,
#    1767     group=parent,
#    1768     mode=mode,
#    1769     synchronizer=synchronizer,
#    1770     consolidated=consolidated,
#    1771     consolidate_on_close=False,
#    1772     chunk_store=chunk_store,
#    1773     storage_options=storage_options,
#    1774     zarr_version=zarr_version,
#    1775     zarr_format=zarr_format,
#    1776 )
#    1778 groups_dict = {}
#    1779 for path_group, store in stores.items():
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/backends/zarr.py:650, in ZarrStore.open_store(cls, store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, append_dim, write_region, safe_chunks, align_chunks, zarr_version, zarr_format, use_zarr_fill_value_as_mask, write_empty, cache_members)
#     624 @classmethod
#     625 def open_store(
#     626     cls,
#    (...)
#     643     cache_members: bool = True,
#     644 ):
#     645     (
#     646         zarr_group,
#     647         consolidate_on_close,
#     648         close_store_on_close,
#     649         use_zarr_fill_value_as_mask,
# --> 650     ) = _get_open_params(
#     651         store=store,
#     652         mode=mode,
#     653         synchronizer=synchronizer,
#     654         group=group,
#     655         consolidated=consolidated,
#     656         consolidate_on_close=consolidate_on_close,
#     657         chunk_store=chunk_store,
#     658         storage_options=storage_options,
#     659         zarr_version=zarr_version,
#     660         use_zarr_fill_value_as_mask=use_zarr_fill_value_as_mask,
#     661         zarr_format=zarr_format,
#     662     )
#     664     from zarr import Group
#     666     group_members: dict[str, Group] = {}
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/backends/zarr.py:1894, in _get_open_params(store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, zarr_version, use_zarr_fill_value_as_mask, zarr_format)
#    1879             emit_user_level_warning(
#    1880                 "Failed to open Zarr store with consolidated metadata, "
#    1881                 "but successfully read with non-consolidated metadata. "
#    (...)
#    1891                 RuntimeWarning,
#    1892             )
#    1893         except missing_exc as err:
# -> 1894             raise FileNotFoundError(
#    1895                 f"No such file or directory: '{store}'"
#    1896             ) from err
#    1898 # but the user should still receive a DataTree whose root is the group they asked for
#    1899 if group and group != "/":
#
# FileNotFoundError: No such file or directory: 'https://objects.eodc.eu:443/e05ab01a9d56408d82ac32d69a5aae2a:202509-s02msil2a-eu/25/products/cpm_v256/S2B_MSIL2A_20250925T112109_N0511_R037_T29TQJ_20250925T151904.zarr'
